# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Andres Salguero/Documents/GitHub/tareas-y-proyectos/ProyectoFinalPython/final.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  depto_id   Departamento  Claro_telecom  Tigo_telecom  \
# 0           0         1      Guatemala        2183312       2117814
# 1           1         2    El Progreso          74472         92667
# 2           2         3   Sacatepequez         213455        176322
# 3           3         4  Chimaltenango         219865        295192
# 4           4         5      Escuintla         359738        417114
#
#    Población_total  Claro_FB  Tigo_FB  T_telecom     T_FB  %FB/Telecom  \
# 0          3015081   2860000  2710000    4301126  5570000     1.295010
# 1           176632     41000    42000     167139    83000     0.496593
# 2           330469    139000   106000     389777   245000     0.628565
# 3           615776    117000   133000     515057   250000     0.485383
# 4           733181    207000   176000     776852   383000     0.493015
#
#      P+15años  %MS_Claro  T_Telecom/P+15años  T_FB/P+15años
# 0  1989953.46   0.507614            2.161420       2.799060
# ...

# %%
df.loc[:, ['Departamento', 'T_FB/P+15años', 'T_Telecom/P+15años' ] ]
# Out:
#       Departamento  T_FB/P+15años  T_Telecom/P+15años
# 0        Guatemala       2.799060            2.161420
# 1      El Progreso       0.711975            1.433720
# 2     Sacatepequez       1.123289            1.787070
# 3    Chimaltenango       0.615139            1.267327
# 4        Escuintla       0.791487            1.605400
# 5       Santa Rosa       0.573043            1.285602
# 6           Solola       0.636131            1.218014
# 7      Totonicapan       0.510397            1.056468
# 8   Quetzaltenango       1.018190            1.569791
# 9    Suchitepequez       0.650098            1.415656
# 10      Retalhuleu       0.709297            1.344206
# 11      San Marcos       1.862608            1.034794
# 12   Huehuetenango       0.599243            0.900220
# 13          Quiche       0.469265            0.811548
# 14    Baja Verapaz       0.551468            0.930044
# 15    Alta Verapaz       0.337937            0.570960
# ...

# %%
df.loc[:, ['Departamento', 'T_FB/P+15años', 'T_Telecom/P+15años' ] ].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df.loc[:, ['Departamento', '%MS_Claro', 'Claro_FB' ] ]
# Out:
#       Departamento  %MS_Claro  Claro_FB
# 0        Guatemala   0.507614   2860000
# 1      El Progreso   0.445569     41000
# 2     Sacatepequez   0.547634    139000
# 3    Chimaltenango   0.426875    117000
# 4        Escuintla   0.463071    207000
# 5       Santa Rosa   0.445864     68000
# 6           Solola   0.420866     75000
# 7      Totonicapan   0.305950     40000
# 8   Quetzaltenango   0.449276    265000
# 9    Suchitepequez   0.544896    163000
# 10      Retalhuleu   0.465015     83000
# 11      San Marcos   0.303104    290000
# 12   Huehuetenango   0.228248     67000
# 13          Quiche   0.256488     67000
# 14    Baja Verapaz   0.379449     38000
# 15    Alta Verapaz   0.239742     57000
# 16           Peten   0.268126     50000
# 17          Izabal   0.343763    105000
# 18          Zacapa   0.323406     41000
# 19      Chiquimula   0.346609     48000
# 20          Jalapa   0.300071     33000
# 21         Jutiapa   0.357248     63000

# %%
df.loc[:, ['Departamento', '%MS_Claro'] ].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANDRES~1\AppData\Local\Temp/ipykernel_11992/3375594786.py in <module>
#       1 df.loc[:, ['Departamento', '%MS_Claro'] ].plot(kind = 'scatter', x = 'Departamento', y = '%MS_Claro')
#       2
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined
